# %%
# Count tracks & videos in excel files and supp. material
import os
from collections import defaultdict
from datetime import datetime
import time
import re
import sys
import pandas as pd
import logging
from PIL import Image

logging.basicConfig(
    level=logging.INFO,
    format="[%(asctime)s] %(message)s",
    datefmt='%d-%b-%y %H:%M:%S',
    handlers=[
        logging.FileHandler(fr'C:\Users\pc\Desktop\mov_sist\\track_descriptive_info_{datetime.now().strftime("%d.%b.%Y_%H.%M.%S")}.txt'),
        logging.StreamHandler(sys.stdout)
    ]
)

t = time.time()

walk_dir = r'C:\Users\pc\Desktop\mov_sist\valid_tracks_700'

logging.info('\n\n\nwalk_dir = ' + walk_dir)
# If your current working directory may change during script execution, it's recommended to
# immediately convert program arguments to an absolute path. Then the variable root below will
# be an absolute path as well.
walk_dir = os.path.abspath(walk_dir)
logging.info('walk_dir (absolute) = ' + os.path.abspath(walk_dir))
excl_list = defaultdict(list)
excl_merged = defaultdict(list)
tracks_quantity = defaultdict()
numreps = defaultdict()
numcells = defaultdict(defaultdict().copy)
max_min_cells = defaultdict(defaultdict().copy)
left_n = defaultdict()
right_n = defaultdict()

for root, subdirs, files in os.walk(walk_dir):
    logging.info(f'\nNOW IN ROOT = {root}\n')
    logging.info(f'\nThere are {len(files)} files in {root}')
    
    for subdir in subdirs:
        logging.info('\t- subdirectory ' + subdir)
    
    for filename in files:
        scenario = root.rsplit('\\',1)[1]
        file_path = os.path.join(root, filename)
        serie = pd.read_excel(file_path, header=None)
        if len(serie)%3600 != 0: # detect misshaped xlsx files
            logging.critical(f'\t- length of {filename} is not a multiple of 3600!')
            raise SystemExit(f'\t- length of {filename} is not a multiple of 3600!')
        else:
            excl_list[scenario].append(serie)
        numcells[scenario][filename] = len(serie)/3600
        o = serie.iloc[0::3600,4] #Coordenadas X iniciales de cada célula en esa serie
        f = serie.iloc[-1::-3600,4].iloc[::-1] #Coordenadas X finales de cada célula en esa serie
        x_displacement_serie = [f_i-o_i for o_i,f_i in zip(o.tolist(), f.tolist())]
        if any(ele == 0 for ele in x_displacement_serie): # detect cells with no displacement
            logging.critical(f'\t- cell(s) nº {[idx for idx, val in enumerate(x_displacement_serie) if val == 0]} have no displacement')
            raise SystemExit(f'\t- cell(s) nº {[idx for idx, val in enumerate(x_displacement_serie) if val == 0]} have no displacement')
        left_n[filename] = sum(1 for value in x_displacement_serie if value < 0 )
        right_n[filename] = sum(1 for value in x_displacement_serie if value > 0 )
        logging.info(f'''\t- video {filename} contains {numcells[scenario][filename]} tracks, of which
        {left_n[filename]} end on the left side and {right_n[filename]} end on the right side, with ratios
        {(left_n[filename]/len(x_displacement_serie))*100}% left and {(right_n[filename]/len(x_displacement_serie))*100}% right''')
    if files: # If folder contains any files do...
        max_min_cells[scenario]['max'] = max(numcells[scenario].values())
        max_min_cells[scenario]['min'] = min(numcells[scenario].values())
        logging.info(f'Max and min number of cells per rep in {scenario} are {max_min_cells[scenario]["min"]}-{max_min_cells[scenario]["max"]}')
        excl_merged[scenario] = pd.concat(excl_list[scenario], ignore_index=True)
        numreps[scenario] = len(files)
        logging.info(f'{scenario} has {numreps[scenario]} replicates (videos)')
        tracks_quantity[scenario] = len(excl_merged[scenario])/3600
        logging.info(f'{scenario} contains {tracks_quantity[scenario]} tracks')
        a = excl_merged[scenario].iloc[0::3600,4] #Coordenadas X iniciales de cada célula en ese escenario
        b = excl_merged[scenario].iloc[-1::-3600,4].iloc[::-1] #Coordenadas X finales de cada célula en ese escenario
        x_displacement_scenario = [b_i-a_i for a_i,b_i in zip(a.tolist(), b.tolist())]
        logging.info(f'Tracks in {scenario} displacement values:{chr(10)}{chr(10).join(map(str,x_displacement_scenario))}')
        left_n[scenario] = sum(1 for value in x_displacement_scenario if value < 0 )
        right_n[scenario] = sum(1 for value in x_displacement_scenario if value > 0 )
        logging.info(f'{scenario} has {right_n[scenario]} cells to the right')
        logging.info(f'{scenario} has {left_n[scenario]} cells to the left')
        logging.info(f'{scenario} has {(left_n[scenario]/len(x_displacement_scenario))*100} left side ratio')
        logging.info(f'{scenario} has {(right_n[scenario]/len(x_displacement_scenario))*100} right side ratio')
    else:
        logging.info(f'\nThere are no files in root: {root}')

logging.info(f'''All the xlsx combined contain {sum((v for v in numreps.values()))}
recorded videos and {sum((len(v) for v in excl_merged.values()))/3600} tracks''')
elapsed = time.time() - t
logging.info(f'{elapsed} seconds elapsed')

# Count "leaf" folders (videos) in the supp. material directory

logging.info(f'{chr(10)}{chr(10)}Now counting videos in Supp. Material and xlsx files in \
"valid_tracks_700" folder...{chr(10)}{chr(10)}')
folders = []
excelfiles = []
supp_material = r'C:\Users\pc\Desktop\mov_sist\Supp_mat'
for root, dirs, files in os.walk(supp_material):
    if not dirs:
        folders.append(os.path.basename(root))
    for file in files:
        if file.endswith(".jpg"):
            excelfiles.append(os.path.join(root, file))
            img = Image.open(os.path.join(root, file))
            wid, hgt = img.size
            logging.info(f'{chr(10)}File {root.split(chr(92),6)[-1]} has {str(wid) + "x" + str(hgt)} resolution')
            break
logging.info(f'There are {len(folders)} videos in Supp. Material and {len(excelfiles)} xlsx files in "valid_tracks_700"{chr(10)}{chr(10)}')
# Out:
# [18-Jul-23 18:41:54]
#
#
# walk_dir = C:\Users\pc\Desktop\mov_sist\valid_tracks_700
# [18-Jul-23 18:41:54] walk_dir (absolute) = C:\Users\pc\Desktop\mov_sist\valid_tracks_700
# [18-Jul-23 18:41:54]
# NOW IN ROOT = C:\Users\pc\Desktop\mov_sist\valid_tracks_700
#
# [18-Jul-23 18:41:54]
# There are 0 files in C:\Users\pc\Desktop\mov_sist\valid_tracks_700
# [18-Jul-23 18:41:54] 	- subdirectory Amoeba borokensis
# [18-Jul-23 18:41:54] 	- subdirectory Amoeba proteus
# [18-Jul-23 18:41:54] 	- subdirectory Metamoeba leningradensis
# [18-Jul-23 18:41:54]
# There are no files in root: C:\Users\pc\Desktop\mov_sist\valid_tracks_700
# [18-Jul-23 18:41:54]
# NOW IN ROOT = C:\Users\pc\Desktop\mov_sist\valid_tracks_700\Amoeba borokensis
#
# [18-Jul-23 18:41:54]
# There are 0 files in C:\Users\pc\Desktop\mov_sist\valid_tracks_700\Amoeba borokensis
# [18-Jul-23 18:41:54] 	- subdirectory Galvanotaxis borokensis 11.63
# [18-Jul-23 18:41:54] 	- subdirectory Induccion borokensis 11.63
# [18-Jul-23 18:41:54] 	- subdirectory Quimiotaxis borokensis 23.44
# [18-Jul-23 18:41:54] 	- subdirectory Sin estimulo borokensis 23.44
# [18-Jul-23 18:41:54]
# There are no files in root: C:\Users\pc\Desktop\mov_sist\valid_tracks_700\Amoeba borokensis
# [18-Jul-23 18:41:54]
# NOW IN ROOT = C:\Users\pc\Desktop\mov_sist\valid_tracks_700\Amoeba borokensis\Galvanotaxis borokensis 11.63
#
# [18-Jul-23 18:41:54]
# There are 8 files in C:\Users\pc\Desktop\mov_sist\valid_tracks_700\Amoeba borokensis\Galvanotaxis borokensis 11.63
# [18-Jul-23 18:42:15] 	- video 2021.10.30_16.58.53.xlsx contains 6.0 tracks, of which
#         0 end on the left side and 6 end on the right side, with ratios
#         0.0% left and 100.0% right
# [18-Jul-23 18:42:36] 	- video 2021.10.30_18.06.37.xlsx contains 6.0 tracks, of which
#         0 end on the left side and 6 end on the right side, with ratios
#         0.0% left and 100.0% right
# [18-Jul-23 18:43:03] 	- video 2021.10.30_21.29.05.xlsx contains 8.0 tracks, of which
#         0 end on the left side and 8 end on the right side, with ratios
#         0.0% left and 100.0% right
# [18-Jul-23 18:43:32] 	- video 2021.10.30_23.13.49.xlsx contains 9.0 tracks, of which
#         0 end on the left side and 9 end on the right side, with ratios
#         0.0% left and 100.0% right
# [18-Jul-23 18:43:42] 	- video 2021.11.01_12.06.40.xlsx contains 3.0 tracks, of which
#         0 end on the left side and 3 end on the right side, with ratios
#         0.0% left and 100.0% right
# [18-Jul-23 18:44:04] 	- video 2021.11.01_17.41.35.xlsx contains 7.0 tracks, of which
#         0 end on the left side and 7 end on the right side, with ratios
#         0.0% left and 100.0% right
# [18-Jul-23 18:44:20] 	- video 2021.11.03_15.19.01.xlsx contains 5.0 tracks, of which
#         0 end on the left side and 5 end on the right side, with ratios
#         0.0% left and 100.0% right
# [18-Jul-23 18:44:39] 	- video 2021.11.03_18.17.35.xlsx contains 6.0 tracks, of which
#         0 end on the left side and 6 end on the right side, with ratios
#         0.0% left and 100.0% right
# [18-Jul-23 18:44:39] Max and min number of cells per rep in Galvanotaxis borokensis 11.63 are 3.0-9.0
# [18-Jul-23 18:44:39] Galvanotaxis borokensis 11.63 has 8 replicates (videos)
# [18-Jul-23 18:44:39] Galvanotaxis borokensis 11.63 contains 50.0 tracks
# [18-Jul-23 18:44:39] Tracks in Galvanotaxis borokensis 11.63 displacement values:
# 26.625
# 34.489000000000004
# 15.0
# 32.0
# 21.25
# 15.417000000000002
# 28.531000000000006
# 48.25
# 23.937000000000012
# 60.43700000000001
# 53.18700000000001
# 38.25
# 17.708
# 118.0
# 33.5
# 45.58300000000003
# 81.91699999999997
# 67.83399999999997
# 26.084000000000003
# 29.667
# 80.5
# 98.68799999999999
# 103.75
# 66.292
# 89.875
# 1.2909999999999968
# 67.125
# 18.25
# 52.0
# 41.417
# 22.5
# 39.666000000000025
# 59.792
# 40.375
# 75.375
# 68.125
# 52.625
# 67.375
# 73.875
# 61.667
# 54.208
# 62.375
# 90.5
# 62.0
# 79.0
# 78.37599999999998
# 54.93700000000001
# 43.333
# 5.936999999999998
# 72.37400000000002
# [18-Jul-23 18:44:39] Galvanotaxis borokensis 11.63 has 50 cells to the right
# [18-Jul-23 18:44:39] Galvanotaxis borokensis 11.63 has 0 cells to the left
# [18-Jul-23 18:44:39] Galvanotaxis borokensis 11.63 has 0.0 left side ratio
# [18-Jul-23 18:44:39] Galvanotaxis borokensis 11.63 has 100.0 right side ratio
# [18-Jul-23 18:44:39]
# NOW IN ROOT = C:\Users\pc\Desktop\mov_sist\valid_tracks_700\Amoeba borokensis\Induccion borokensis 11.63
#
# [18-Jul-23 18:44:39]
# There are 12 files in C:\Users\pc\Desktop\mov_sist\valid_tracks_700\Amoeba borokensis\Induccion borokensis 11.63
# [18-Jul-23 18:44:56] 	- video 2020.07.30_18.20.54.xlsx contains 5.0 tracks, of which
#         1 end on the left side and 4 end on the right side, with ratios
#         20.0% left and 80.0% right
# [18-Jul-23 18:45:10] 	- video 2020.07.31_17.55.40.xlsx contains 4.0 tracks, of which
#         2 end on the left side and 2 end on the right side, with ratios
#         50.0% left and 50.0% right
# [18-Jul-23 18:45:32] 	- video 2020.08.04_13.01.00.xlsx contains 7.0 tracks, of which
#         3 end on the left side and 4 end on the right side, with ratios
#         42.857142857142854% left and 57.14285714285714% right
# [18-Jul-23 18:45:58] 	- video 2020.08.04_15.48.12.xlsx contains 7.0 tracks, of which
#         2 end on the left side and 5 end on the right side, with ratios
#         28.57142857142857% left and 71.42857142857143% right
# [18-Jul-23 18:46:28] 	- video 2020.08.05_12.39.52.xlsx contains 7.0 tracks, of which
#         6 end on the left side and 1 end on the right side, with ratios
#         85.71428571428571% left and 14.285714285714285% right
# [18-Jul-23 18:46:56] 	- video 2020.08.06_12.46.49.xlsx contains 7.0 tracks, of which
#         5 end on the left side and 2 end on the right side, with ratios
#         71.42857142857143% left and 28.57142857142857% right
# [18-Jul-23 18:47:28] 	- video 2020.08.06_15.42.17.xlsx contains 7.0 tracks, of which
#         1 end on the left side and 6 end on the right side, with ratios
#         14.285714285714285% left and 85.71428571428571% right
# [18-Jul-23 18:47:55] 	- video 2020.08.06_17.49.36.xlsx contains 7.0 tracks, of which
#         5 end on the left side and 2 end on the right side, with ratios
#         71.42857142857143% left and 28.57142857142857% right
# [18-Jul-23 18:48:24] 	- video 2020.08.07_13.48.20.xlsx contains 8.0 tracks, of which
#         4 end on the left side and 4 end on the right side, with ratios
#         50.0% left and 50.0% right
# [18-Jul-23 18:48:50] 	- video 2020.08.07_19.00.26.xlsx contains 7.0 tracks, of which
#         3 end on the left side and 4 end on the right side, with ratios
#         42.857142857142854% left and 57.14285714285714% right
# [18-Jul-23 18:49:11] 	- video 2022.10.28_13.36.04.xlsx contains 6.0 tracks, of which
#         5 end on the left side and 1 end on the right side, with ratios
#         83.33333333333334% left and 16.666666666666664% right
# [18-Jul-23 18:49:33] 	- video 2022.10.28_15.52.33.xlsx contains 6.0 tracks, of which
#         6 end on the left side and 0 end on the right side, with ratios
#         100.0% left and 0.0% right
# [18-Jul-23 18:49:33] Max and min number of cells per rep in Induccion borokensis 11.63 are 4.0-8.0
# [18-Jul-23 18:49:33] Induccion borokensis 11.63 has 12 replicates (videos)
# [18-Jul-23 18:49:33] Induccion borokensis 11.63 contains 78.0 tracks
# [18-Jul-23 18:49:33] Tracks in Induccion borokensis 11.63 displacement values:
# -13.14500000000001
# 55.68799999999999
# 18.374000000000024
# 9.915999999999997
# 25.458
# -6.332999999999998
# -9.584000000000003
# 26.75
# 24.375
# -15.85499999999999
# -7.770999999999987
# -10.832999999999998
# 16.584000000000003
# 22.833999999999975
# 24.75
# 7.0
# -17.084000000000003
# -8.584000000000003
# 35.66699999999997
# 47.0
# 57.875
# 38.666000000000025
# 21.165999999999997
# -30.958
# -38.125
# -54.64500000000001
# -40.875
# -4.957999999999998
# -1.322999999999979
# 31.666999999999973
# -135.125
# -78.93799999999999
# -29.551999999999992
# -83.344
# -62.781000000000006
# 12.040999999999997
# 14.093000000000018
# -14.0
# 26.312000000000012
# 42.333999999999975
# 10.406999999999982
# 38.5
# 11.916000000000054
# 38.125999999999976
# -3.0829999999999984
# -3.812000000000012
# -26.604000000000013
# -4.562000000000012
# 36.75
# 27.5
# -2.187999999999988
# -104.68700000000001
# -52.75
# -17.687000000000012
# -21.812999999999988
# 52.0
# 46.416000000000025
# 4.625999999999976
# 96.25
# 22.062000000000012
# 1.875
# 76.375
# -7.062000000000012
# 5.791000000000054
# -26.125
# -35.833
# -11.968999999999994
# -50.281000000000006
# -161.969
# -78.219
# -89.68799999999999
# 12.5
# -114.34300000000002
# -68.406
# -41.843999999999994
# -71.594
# -45.31200000000001
# -73.40699999999998
# [18-Jul-23 18:49:33] Induccion borokensis 11.63 has 35 cells to the right
# [18-Jul-23 18:49:33] Induccion borokensis 11.63 has 43 cells to the left
# [18-Jul-23 18:49:33] Induccion borokensis 11.63 has 55.12820512820513 left side ratio
# [18-Jul-23 18:49:33] Induccion borokensis 11.63 has 44.871794871794876 right side ratio
# [18-Jul-23 18:49:33]
# NOW IN ROOT = C:\Users\pc\Desktop\mov_sist\valid_tracks_700\Amoeba borokensis\Quimiotaxis borokensis 23.44
#
# [18-Jul-23 18:49:33]
# There are 10 files in C:\Users\pc\Desktop\mov_sist\valid_tracks_700\Amoeba borokensis\Quimiotaxis borokensis 23.44
# [18-Jul-23 18:49:53] 	- video 2020.07.17_17.14.13.xlsx contains 5.0 tracks, of which
#         3 end on the left side and 2 end on the right side, with ratios
#         60.0% left and 40.0% right
# [18-Jul-23 18:50:09] 	- video 2020.07.17_19.27.02.xlsx contains 5.0 tracks, of which
#         3 end on the left side and 2 end on the right side, with ratios
#         60.0% left and 40.0% right
# [18-Jul-23 18:50:27] 	- video 2020.07.20_14.41.07.xlsx contains 5.0 tracks, of which
#         4 end on the left side and 1 end on the right side, with ratios
#         80.0% left and 20.0% right
# [18-Jul-23 18:50:44] 	- video 2020.07.20_16.09.39.xlsx contains 5.0 tracks, of which
#         4 end on the left side and 1 end on the right side, with ratios
#         80.0% left and 20.0% right
# [18-Jul-23 18:51:07] 	- video 2020.07.20_16.57.05.xlsx contains 6.0 tracks, of which
#         4 end on the left side and 2 end on the right side, with ratios
#         66.66666666666666% left and 33.33333333333333% right
# [18-Jul-23 18:51:23] 	- video 2020.07.20_19.50.14.xlsx contains 5.0 tracks, of which
#         4 end on the left side and 1 end on the right side, with ratios
#         80.0% left and 20.0% right
# [18-Jul-23 18:51:46] 	- video 2022.10.25_20.47.05.xlsx contains 7.0 tracks, of which
#         4 end on the left side and 3 end on the right side, with ratios
#         57.14285714285714% left and 42.857142857142854% right
# [18-Jul-23 18:52:07] 	- video 2022.10.25_21.53.16.xlsx contains 6.0 tracks, of which
#         5 end on the left side and 1 end on the right side, with ratios
#         83.33333333333334% left and 16.666666666666664% right
# [18-Jul-23 18:52:22] 	- video 2022.10.26_18.28.56.xlsx contains 5.0 tracks, of which
#         3 end on the left side and 2 end on the right side, with ratios
#         60.0% left and 40.0% right
# [18-Jul-23 18:52:39] 	- video 2022.10.26_19.39.33.xlsx contains 6.0 tracks, of which
#         5 end on the left side and 1 end on the right side, with ratios
#         83.33333333333334% left and 16.666666666666664% right
# [18-Jul-23 18:52:39] Max and min number of cells per rep in Quimiotaxis borokensis 23.44 are 5.0-7.0
# [18-Jul-23 18:52:39] Quimiotaxis borokensis 23.44 has 10 replicates (videos)
# [18-Jul-23 18:52:39] Quimiotaxis borokensis 23.44 contains 55.0 tracks
# [18-Jul-23 18:52:39] Tracks in Quimiotaxis borokensis 23.44 displacement values:
# -24.80200000000002
# -55.95800000000003
# -42.5
# 67.25
# 25.375
# -14.666999999999973
# -9.031999999999982
# -53.75
# 10.125
# 70.25
# -86.50000000000003
# -5.260999999999967
# -67.5
# -23.25
# 54.875
# -41.5
# -1.6870000000000118
# -35.083999999999946
# -79.25
# 24.25
# -6.541000000000054
# -92.41699999999997
# -14.801999999999992
# -5.041999999999973
# 19.666000000000054
# 175.875
# -55.5
# -2.625
# -71.0
# -11.728999999999985
# 34.625999999999976
# -209.33300000000003
# -109.33399999999997
# -162.75
# 22.083999999999946
# -16.875
# 91.875
# 80.875
# -20.75
# -13.583000000000027
# -4.625
# -1.875
# 79.66600000000005
# -97.16699999999997
# -234.75
# -158.625
# -273.625
# 63.08300000000003
# 171.00000000000006
# -101.75
# -93.375
# -55.33300000000003
# 43.125
# -44.5
# -131.5
# [18-Jul-23 18:52:39] Quimiotaxis borokensis 23.44 has 16 cells to the right
# [18-Jul-23 18:52:39] Quimiotaxis borokensis 23.44 has 39 cells to the left
# [18-Jul-23 18:52:39] Quimiotaxis borokensis 23.44 has 70.9090909090909 left side ratio
# [18-Jul-23 18:52:39] Quimiotaxis borokensis 23.44 has 29.09090909090909 right side ratio
# [18-Jul-23 18:52:39]
# NOW IN ROOT = C:\Users\pc\Desktop\mov_sist\valid_tracks_700\Amoeba borokensis\Sin estimulo borokensis 23.44
#
# [18-Jul-23 18:52:39]
# There are 7 files in C:\Users\pc\Desktop\mov_sist\valid_tracks_700\Amoeba borokensis\Sin estimulo borokensis 23.44
# [18-Jul-23 18:52:57] 	- video 2020.07.21_15.28.46.xlsx contains 6.0 tracks, of which
#         5 end on the left side and 1 end on the right side, with ratios
#         83.33333333333334% left and 16.666666666666664% right
# [18-Jul-23 18:53:23] 	- video 2020.07.21_16.18.37.xlsx contains 8.0 tracks, of which
#         5 end on the left side and 3 end on the right side, with ratios
#         62.5% left and 37.5% right
# [18-Jul-23 18:53:52] 	- video 2020.07.21_17.12.34.xlsx contains 8.0 tracks, of which
#         3 end on the left side and 5 end on the right side, with ratios
#         37.5% left and 62.5% right
# [18-Jul-23 18:54:13] 	- video 2020.07.21_18.12.37.xlsx contains 7.0 tracks, of which
#         2 end on the left side and 5 end on the right side, with ratios
#         28.57142857142857% left and 71.42857142857143% right
# [18-Jul-23 18:54:36] 	- video 2020.07.22_12.38.04.xlsx contains 8.0 tracks, of which
#         3 end on the left side and 5 end on the right side, with ratios
#         37.5% left and 62.5% right
# [18-Jul-23 18:54:56] 	- video 2020.07.22_13.25.22.xlsx contains 7.0 tracks, of which
#         2 end on the left side and 5 end on the right side, with ratios
#         28.57142857142857% left and 71.42857142857143% right
# [18-Jul-23 18:55:20] 	- video 2020.07.22_15.23.06.xlsx contains 8.0 tracks, of which
#         5 end on the left side and 3 end on the right side, with ratios
#         62.5% left and 37.5% right
# [18-Jul-23 18:55:20] Max and min number of cells per rep in Sin estimulo borokensis 23.44 are 6.0-8.0
# [18-Jul-23 18:55:20] Sin estimulo borokensis 23.44 has 7 replicates (videos)
# [18-Jul-23 18:55:20] Sin estimulo borokensis 23.44 contains 52.0 tracks
# [18-Jul-23 18:55:20] Tracks in Sin estimulo borokensis 23.44 displacement values:
# -56.125
# -58.08300000000003
# 21.75
# -7.0
# -66.25
# -6.375
# 23.166999999999973
# -92.5
# 89.25
# -27.166999999999973
# -84.0
# -27.583000000000027
# 67.875
# -7.093999999999994
# -31.33299999999997
# -2.75
# 16.75
# -0.875
# 67.844
# 101.70800000000003
# 34.125
# 39.79199999999997
# 93.125
# -7.583000000000027
# 60.218999999999994
# 83.08300000000003
# 27.416999999999973
# 15.0
# -39.16699999999997
# 60.166000000000054
# 77.91699999999997
# 10.125999999999976
# 131.41699999999997
# -6.062000000000012
# 52.375
# -88.43700000000001
# -33.95800000000003
# 120.0
# -105.66699999999997
# 43.04199999999997
# 102.875
# -146.49999999999997
# 44.66699999999997
# 58.17700000000002
# 1.0839999999999463
# 8.041000000000054
# -17.25
# -46.875
# -17.375
# 5.125
# -111.125
# -27.375
# [18-Jul-23 18:55:20] Sin estimulo borokensis 23.44 has 27 cells to the right
# [18-Jul-23 18:55:20] Sin estimulo borokensis 23.44 has 25 cells to the left
# [18-Jul-23 18:55:20] Sin estimulo borokensis 23.44 has 48.07692307692308 left side ratio
# [18-Jul-23 18:55:20] Sin estimulo borokensis 23.44 has 51.92307692307693 right side ratio
# [18-Jul-23 18:55:20]
# NOW IN ROOT = C:\Users\pc\Desktop\mov_sist\valid_tracks_700\Amoeba proteus
#
# [18-Jul-23 18:55:20]
# There are 0 files in C:\Users\pc\Desktop\mov_sist\valid_tracks_700\Amoeba proteus
# [18-Jul-23 18:55:20] 	- subdirectory Galvanotaxis proteus 11.63
# [18-Jul-23 18:55:20] 	- subdirectory Induccion proteus 11.63
# [18-Jul-23 18:55:20] 	- subdirectory Quimiotaxis proteus 11.63
# [18-Jul-23 18:55:20] 	- subdirectory Sin estimulo proteus 11.63
# [18-Jul-23 18:55:20]
# There are no files in root: C:\Users\pc\Desktop\mov_sist\valid_tracks_700\Amoeba proteus
# [18-Jul-23 18:55:20]
# NOW IN ROOT = C:\Users\pc\Desktop\mov_sist\valid_tracks_700\Amoeba proteus\Galvanotaxis proteus 11.63
#
# [18-Jul-23 18:55:20]
# There are 7 files in C:\Users\pc\Desktop\mov_sist\valid_tracks_700\Amoeba proteus\Galvanotaxis proteus 11.63
# [18-Jul-23 18:55:39] 	- video 2020.08.25_17.50.03.xlsx contains 6.0 tracks, of which
#         0 end on the left side and 6 end on the right side, with ratios
#         0.0% left and 100.0% right
# [18-Jul-23 18:55:59] 	- video 2020.08.25_18.39.52.xlsx contains 7.0 tracks, of which
#         0 end on the left side and 7 end on the right side, with ratios
#         0.0% left and 100.0% right
# [18-Jul-23 18:56:19] 	- video 2020.08.25_19.36.11.xlsx contains 7.0 tracks, of which
#         0 end on the left side and 7 end on the right side, with ratios
#         0.0% left and 100.0% right
# [18-Jul-23 18:56:39] 	- video 2020.08.26_12.22.06.xlsx contains 7.0 tracks, of which
#         0 end on the left side and 7 end on the right side, with ratios
#         0.0% left and 100.0% right
# [18-Jul-23 18:56:59] 	- video 2020.08.26_13.21.04.xlsx contains 7.0 tracks, of which
#         0 end on the left side and 7 end on the right side, with ratios
#         0.0% left and 100.0% right
# [18-Jul-23 18:57:20] 	- video 2020.08.26_14.13.56.xlsx contains 7.0 tracks, of which
#         0 end on the left side and 7 end on the right side, with ratios
#         0.0% left and 100.0% right
# [18-Jul-23 18:57:43] 	- video 2020.08.26_16.59.42.xlsx contains 8.0 tracks, of which
#         0 end on the left side and 8 end on the right side, with ratios
#         0.0% left and 100.0% right
# [18-Jul-23 18:57:43] Max and min number of cells per rep in Galvanotaxis proteus 11.63 are 6.0-8.0
# [18-Jul-23 18:57:43] Galvanotaxis proteus 11.63 has 7 replicates (videos)
# [18-Jul-23 18:57:43] Galvanotaxis proteus 11.63 contains 49.0 tracks
# [18-Jul-23 18:57:43] Tracks in Galvanotaxis proteus 11.63 displacement values:
# 96.0
# 91.06200000000001
# 107.56200000000001
# 111.56299999999999
# 89.31299999999999
# 82.75
# 61.021000000000015
# 121.833
# 18.85499999999999
# 49.16699999999997
# 26.0
# 26.5
# 50.33300000000003
# 131.625
# 67.66699999999997
# 101.33300000000003
# 134.188
# 23.625
# 89.625
# 104.875
# 68.31200000000001
# 38.958
# 65.375
# 90.5
# 90.16699999999997
# 94.58399999999997
# 52.68799999999999
# 111.66699999999997
# 79.875
# 111.875
# 16.458000000000027
# 53.70800000000003
# 127.91699999999997
# 148.25
# 67.16699999999997
# 17.125
# 10.25
# 75.81200000000001
# 85.33399999999997
# 65.37599999999998
# 76.56200000000001
# 68.18799999999999
# 129.77000000000004
# 71.25
# 78.541
# 65.531
# 69.5
# 79.20800000000003
# 72.833
# [18-Jul-23 18:57:43] Galvanotaxis proteus 11.63 has 49 cells to the right
# [18-Jul-23 18:57:43] Galvanotaxis proteus 11.63 has 0 cells to the left
# [18-Jul-23 18:57:43] Galvanotaxis proteus 11.63 has 0.0 left side ratio
# [18-Jul-23 18:57:43] Galvanotaxis proteus 11.63 has 100.0 right side ratio
# [18-Jul-23 18:57:43]
# NOW IN ROOT = C:\Users\pc\Desktop\mov_sist\valid_tracks_700\Amoeba proteus\Induccion proteus 11.63
#
# [18-Jul-23 18:57:43]
# There are 12 files in C:\Users\pc\Desktop\mov_sist\valid_tracks_700\Amoeba proteus\Induccion proteus 11.63
# [18-Jul-23 18:58:04] 	- video 2020.09.15_18.12.02.xlsx contains 7.0 tracks, of which
#         4 end on the left side and 3 end on the right side, with ratios
#         57.14285714285714% left and 42.857142857142854% right
# [18-Jul-23 18:58:22] 	- video 2020.09.16_10.39.01.xlsx contains 6.0 tracks, of which
#         3 end on the left side and 3 end on the right side, with ratios
#         50.0% left and 50.0% right
# [18-Jul-23 18:58:45] 	- video 2020.09.16_12.22.29.xlsx contains 8.0 tracks, of which
#         6 end on the left side and 2 end on the right side, with ratios
#         75.0% left and 25.0% right
# [18-Jul-23 18:59:10] 	- video 2020.09.16_18.04.32.xlsx contains 8.0 tracks, of which
#         4 end on the left side and 4 end on the right side, with ratios
#         50.0% left and 50.0% right
# [18-Jul-23 18:59:30] 	- video 2020.09.17_12.09.09.xlsx contains 7.0 tracks, of which
#         2 end on the left side and 5 end on the right side, with ratios
#         28.57142857142857% left and 71.42857142857143% right
# [18-Jul-23 18:59:47] 	- video 2020.09.17_16.26.11.xlsx contains 6.0 tracks, of which
#         3 end on the left side and 3 end on the right side, with ratios
#         50.0% left and 50.0% right
# [18-Jul-23 19:00:08] 	- video 2020.09.17_18.10.05.xlsx contains 7.0 tracks, of which
#         5 end on the left side and 2 end on the right side, with ratios
#         71.42857142857143% left and 28.57142857142857% right
# [18-Jul-23 19:00:25] 	- video 2020.09.18_13.54.17.xlsx contains 6.0 tracks, of which
#         2 end on the left side and 4 end on the right side, with ratios
#         33.33333333333333% left and 66.66666666666666% right
# [18-Jul-23 19:00:46] 	- video 2020.09.18_15.37.13.xlsx contains 7.0 tracks, of which
#         6 end on the left side and 1 end on the right side, with ratios
#         85.71428571428571% left and 14.285714285714285% right
# [18-Jul-23 19:01:06] 	- video 2020.09.18_17.22.01.xlsx contains 7.0 tracks, of which
#         6 end on the left side and 1 end on the right side, with ratios
#         85.71428571428571% left and 14.285714285714285% right
# [18-Jul-23 19:01:29] 	- video 2020.09.21_15.11.27.xlsx contains 8.0 tracks, of which
#         4 end on the left side and 4 end on the right side, with ratios
#         50.0% left and 50.0% right
# [18-Jul-23 19:01:47] 	- video 2020.09.21_18.19.44.xlsx contains 6.0 tracks, of which
#         5 end on the left side and 1 end on the right side, with ratios
#         83.33333333333334% left and 16.666666666666664% right
# [18-Jul-23 19:01:47] Max and min number of cells per rep in Induccion proteus 11.63 are 6.0-8.0
# [18-Jul-23 19:01:47] Induccion proteus 11.63 has 12 replicates (videos)
# [18-Jul-23 19:01:47] Induccion proteus 11.63 contains 83.0 tracks
# [18-Jul-23 19:01:47] Tracks in Induccion proteus 11.63 displacement values:
# -43.584
# -3.165999999999997
# -3.665999999999997
# -34.5
# 61.43799999999999
# 29.812000000000012
# 43.93700000000001
# -18.208
# -29.5
# 48.583999999999975
# -2.125
# 12.75
# 76.125
# -79.416
# -60.917
# -38.292
# -49.042
# -37.75
# -21.0
# 51.874000000000024
# 49.18700000000001
# -30.5
# -7.417000000000002
# -8.584000000000003
# -83.0
# 2.687000000000012
# 27.687000000000012
# 15.000000000000028
# 90.33300000000003
# -75.417
# -29.5
# 60.5
# 6.656999999999982
# 71.75
# 62.18700000000001
# 21.437000000000012
# -70.5
# -16.667
# -13.917000000000002
# 45.50000000000003
# 17.25
# 2.8329999999999984
# -26.75
# -28.323000000000008
# -38.333999999999975
# -104.68700000000001
# -39.5
# 50.625
# 2.084000000000003
# -22.292
# 14.843999999999994
# 24.5
# 5.332999999999998
# -8.75
# 17.958
# -31.5
# -13.25
# -31.0
# -53.875
# -6.791999999999973
# -3.7499999999999716
# 51.75
# -82.0
# -74.583
# -29.25
# -22.583
# -11.834000000000003
# 4.25
# -25.00000000000003
# -31.917
# -83.469
# -36.042
# -27.25
# 58.43799999999999
# 14.125999999999976
# 63.06299999999999
# 61.124000000000024
# -94.0
# -67.75
# -34.0
# -51.89500000000001
# -15.25
# 46.25
# [18-Jul-23 19:01:47] Induccion proteus 11.63 has 33 cells to the right
# [18-Jul-23 19:01:47] Induccion proteus 11.63 has 50 cells to the left
# [18-Jul-23 19:01:47] Induccion proteus 11.63 has 60.24096385542169 left side ratio
# [18-Jul-23 19:01:47] Induccion proteus 11.63 has 39.75903614457831 right side ratio
# [18-Jul-23 19:01:47]
# NOW IN ROOT = C:\Users\pc\Desktop\mov_sist\valid_tracks_700\Amoeba proteus\Quimiotaxis proteus 11.63
#
# [18-Jul-23 19:01:47]
# There are 8 files in C:\Users\pc\Desktop\mov_sist\valid_tracks_700\Amoeba proteus\Quimiotaxis proteus 11.63
# [18-Jul-23 19:02:01] 	- video 2020.08.24_16.34.56.xlsx contains 5.0 tracks, of which
#         2 end on the left side and 3 end on the right side, with ratios
#         40.0% left and 60.0% right
# [18-Jul-23 19:02:21] 	- video 2020.08.24_17.24.57.xlsx contains 7.0 tracks, of which
#         3 end on the left side and 4 end on the right side, with ratios
#         42.857142857142854% left and 57.14285714285714% right
# [18-Jul-23 19:02:42] 	- video 2020.08.24_18.16.56.xlsx contains 7.0 tracks, of which
#         6 end on the left side and 1 end on the right side, with ratios
#         85.71428571428571% left and 14.285714285714285% right
# [18-Jul-23 19:03:02] 	- video 2020.08.24_19.08.36.xlsx contains 7.0 tracks, of which
#         6 end on the left side and 1 end on the right side, with ratios
#         85.71428571428571% left and 14.285714285714285% right
# [18-Jul-23 19:03:17] 	- video 2020.08.24_19.54.30.xlsx contains 5.0 tracks, of which
#         4 end on the left side and 1 end on the right side, with ratios
#         80.0% left and 20.0% right
# [18-Jul-23 19:03:37] 	- video 2020.08.25_12.52.52.xlsx contains 7.0 tracks, of which
#         7 end on the left side and 0 end on the right side, with ratios
#         100.0% left and 0.0% right
# [18-Jul-23 19:03:56] 	- video 2020.08.25_13.48.41.xlsx contains 7.0 tracks, of which
#         7 end on the left side and 0 end on the right side, with ratios
#         100.0% left and 0.0% right
# [18-Jul-23 19:04:13] 	- video 2020.08.25_15.48.11.xlsx contains 6.0 tracks, of which
#         6 end on the left side and 0 end on the right side, with ratios
#         100.0% left and 0.0% right
# [18-Jul-23 19:04:13] Max and min number of cells per rep in Quimiotaxis proteus 11.63 are 5.0-7.0
# [18-Jul-23 19:04:13] Quimiotaxis proteus 11.63 has 8 replicates (videos)
# [18-Jul-23 19:04:13] Quimiotaxis proteus 11.63 contains 51.0 tracks
# [18-Jul-23 19:04:13] Tracks in Quimiotaxis proteus 11.63 displacement values:
# -24.167
# -22.208
# 6.312999999999988
# 65.25
# 8.415999999999997
# -60.125
# -11.917000000000002
# -17.915999999999997
# 25.583999999999946
# 43.083999999999975
# 5.667000000000002
# 68.5
# -17.167
# -58.625
# -96.06200000000001
# -30.062000000000012
# -63.625
# -37.781000000000006
# 16.084000000000003
# -2.0
# -17.624000000000024
# -36.874000000000024
# -57.708
# -55.68700000000001
# -23.937999999999988
# 6.875
# -20.25
# -43.416
# -61.5
# -8.832999999999998
# 17.062000000000012
# -116.625
# -144.25
# -42.75
# -101.25
# -105.375
# -48.375
# -74.75
# -65.0
# -45.99999999999997
# -58.833999999999975
# -80.83300000000003
# -14.334000000000003
# -60.583
# -9.75
# -29.459000000000003
# -3.125
# -38.24999999999997
# -9.834000000000003
# -10.85499999999999
# -37.99999999999997
# [18-Jul-23 19:04:13] Quimiotaxis proteus 11.63 has 10 cells to the right
# [18-Jul-23 19:04:13] Quimiotaxis proteus 11.63 has 41 cells to the left
# [18-Jul-23 19:04:13] Quimiotaxis proteus 11.63 has 80.3921568627451 left side ratio
# [18-Jul-23 19:04:13] Quimiotaxis proteus 11.63 has 19.607843137254903 right side ratio
# [18-Jul-23 19:04:13]
# NOW IN ROOT = C:\Users\pc\Desktop\mov_sist\valid_tracks_700\Amoeba proteus\Sin estimulo proteus 11.63
#
# [18-Jul-23 19:04:13]
# There are 7 files in C:\Users\pc\Desktop\mov_sist\valid_tracks_700\Amoeba proteus\Sin estimulo proteus 11.63
# [18-Jul-23 19:04:36] 	- video 2020.07.28_10.14.02.xlsx contains 8.0 tracks, of which
#         6 end on the left side and 2 end on the right side, with ratios
#         75.0% left and 25.0% right
# [18-Jul-23 19:04:58] 	- video 2020.07.28_11.08.07.xlsx contains 7.0 tracks, of which
#         2 end on the left side and 5 end on the right side, with ratios
#         28.57142857142857% left and 71.42857142857143% right
# [18-Jul-23 19:05:21] 	- video 2020.07.28_12.05.23.xlsx contains 7.0 tracks, of which
#         1 end on the left side and 6 end on the right side, with ratios
#         14.285714285714285% left and 85.71428571428571% right
# [18-Jul-23 19:05:41] 	- video 2020.07.28_12.55.08.xlsx contains 7.0 tracks, of which
#         2 end on the left side and 5 end on the right side, with ratios
#         28.57142857142857% left and 71.42857142857143% right
# [18-Jul-23 19:06:01] 	- video 2020.07.28_13.44.18.xlsx contains 7.0 tracks, of which
#         3 end on the left side and 4 end on the right side, with ratios
#         42.857142857142854% left and 57.14285714285714% right
# [18-Jul-23 19:06:22] 	- video 2020.07.28_15.33.46.xlsx contains 7.0 tracks, of which
#         4 end on the left side and 3 end on the right side, with ratios
#         57.14285714285714% left and 42.857142857142854% right
# [18-Jul-23 19:06:43] 	- video 2020.07.28_16.26.24.xlsx contains 7.0 tracks, of which
#         2 end on the left side and 5 end on the right side, with ratios
#         28.57142857142857% left and 71.42857142857143% right
# [18-Jul-23 19:06:43] Max and min number of cells per rep in Sin estimulo proteus 11.63 are 7.0-8.0
# [18-Jul-23 19:06:43] Sin estimulo proteus 11.63 has 7 replicates (videos)
# [18-Jul-23 19:06:43] Sin estimulo proteus 11.63 contains 50.0 tracks
# [18-Jul-23 19:06:43] Tracks in Sin estimulo proteus 11.63 displacement values:
# 3.312000000000012
# -64.406
# -27.584000000000003
# -42.30199999999999
# -40.208
# -31.040999999999997
# -6.333000000000027
# 69.5
# 29.875
# 10.417000000000002
# -26.665999999999997
# 60.75
# 44.458
# -40.56200000000001
# 60.66699999999997
# 11.5
# 47.125
# -28.625
# 3.7079999999999984
# 56.083999999999975
# 39.49999999999997
# 43.093999999999994
# 99.29199999999997
# -0.375
# 21.062000000000012
# 16.625
# 111.167
# -0.1670000000000016
# 42.625
# -103.834
# 107.156
# 95.5
# -34.875
# -6.207999999999998
# 31.458
# 116.625
# 115.844
# 130.167
# -0.18799999999998818
# -32.167
# -0.625
# -15.25
# 100.625
# -29.323000000000008
# 141.00000000000003
# 12.25
# 88.27100000000002
# -0.18700000000001182
# 92.261
# 15.687999999999988
# [18-Jul-23 19:06:43] Sin estimulo proteus 11.63 has 30 cells to the right
# [18-Jul-23 19:06:43] Sin estimulo proteus 11.63 has 20 cells to the left
# [18-Jul-23 19:06:43] Sin estimulo proteus 11.63 has 40.0 left side ratio
# [18-Jul-23 19:06:43] Sin estimulo proteus 11.63 has 60.0 right side ratio
# [18-Jul-23 19:06:43]
# NOW IN ROOT = C:\Users\pc\Desktop\mov_sist\valid_tracks_700\Metamoeba leningradensis
#
# [18-Jul-23 19:06:43]
# There are 0 files in C:\Users\pc\Desktop\mov_sist\valid_tracks_700\Metamoeba leningradensis
# [18-Jul-23 19:06:43] 	- subdirectory Galvanotaxis leningradensis 11.63
# [18-Jul-23 19:06:43] 	- subdirectory Induccion leningradensis 11.63
# [18-Jul-23 19:06:43] 	- subdirectory Quimiotaxis leningradensis varios ppmm
# [18-Jul-23 19:06:43] 	- subdirectory Sin estimulo leningradensis 11.63
# [18-Jul-23 19:06:43]
# There are no files in root: C:\Users\pc\Desktop\mov_sist\valid_tracks_700\Metamoeba leningradensis
# [18-Jul-23 19:06:43]
# NOW IN ROOT = C:\Users\pc\Desktop\mov_sist\valid_tracks_700\Metamoeba leningradensis\Galvanotaxis leningradensis 11.63
#
# [18-Jul-23 19:06:43]
# There are 7 files in C:\Users\pc\Desktop\mov_sist\valid_tracks_700\Metamoeba leningradensis\Galvanotaxis leningradensis 11.63
# [18-Jul-23 19:07:00] 	- video 2021.11.02_12.30.49.xlsx contains 6.0 tracks, of which
#         0 end on the left side and 6 end on the right side, with ratios
#         0.0% left and 100.0% right
# [18-Jul-23 19:07:18] 	- video 2021.11.02_14.19.47.xlsx contains 6.0 tracks, of which
#         0 end on the left side and 6 end on the right side, with ratios
#         0.0% left and 100.0% right
# [18-Jul-23 19:07:39] 	- video 2021.11.02_16.29.53.xlsx contains 7.0 tracks, of which
#         0 end on the left side and 7 end on the right side, with ratios
#         0.0% left and 100.0% right
# [18-Jul-23 19:08:02] 	- video 2021.11.02_17.49.06.xlsx contains 8.0 tracks, of which
#         0 end on the left side and 8 end on the right side, with ratios
#         0.0% left and 100.0% right
# [18-Jul-23 19:08:20] 	- video 2021.11.02_22.03.57.xlsx contains 6.0 tracks, of which
#         0 end on the left side and 6 end on the right side, with ratios
#         0.0% left and 100.0% right
# [18-Jul-23 19:08:41] 	- video 2021.11.03_19.13.54.xlsx contains 7.0 tracks, of which
#         0 end on the left side and 7 end on the right side, with ratios
#         0.0% left and 100.0% right
# [18-Jul-23 19:09:05] 	- video 2021.11.05_13.32.29.xlsx contains 8.0 tracks, of which
#         0 end on the left side and 8 end on the right side, with ratios
#         0.0% left and 100.0% right
# [18-Jul-23 19:09:05] Max and min number of cells per rep in Galvanotaxis leningradensis 11.63 are 6.0-8.0
# [18-Jul-23 19:09:05] Galvanotaxis leningradensis 11.63 has 7 replicates (videos)
# [18-Jul-23 19:09:05] Galvanotaxis leningradensis 11.63 contains 48.0 tracks
# [18-Jul-23 19:09:05] Tracks in Galvanotaxis leningradensis 11.63 displacement values:
# 139.16699999999997
# 60.25
# 48.792
# 18.542
# 36.406000000000006
# 29.281000000000006
# 64.625
# 70.5
# 54.25
# 46.625
# 34.334
# 64.334
# 110.875
# 80.81299999999999
# 19.75
# 128.0
# 13.375
# 89.125
# 157.687
# 57.084
# 46.667
# 58.625
# 75.75
# 60.19800000000001
# 61.542
# 19.25
# 65.5
# 91.45800000000003
# 99.75
# 114.125
# 28.25
# 59.125
# 72.0
# 9.832999999999998
# 48.18799999999999
# 35.43799999999999
# 52.125
# 71.5
# 82.5
# 50.75
# 137.875
# 87.0
# 57.375
# 62.25
# 85.917
# 40.25
# 61.5
# 115.75
# [18-Jul-23 19:09:05] Galvanotaxis leningradensis 11.63 has 48 cells to the right
# [18-Jul-23 19:09:05] Galvanotaxis leningradensis 11.63 has 0 cells to the left
# [18-Jul-23 19:09:05] Galvanotaxis leningradensis 11.63 has 0.0 left side ratio
# [18-Jul-23 19:09:05] Galvanotaxis leningradensis 11.63 has 100.0 right side ratio
# [18-Jul-23 19:09:05]
# NOW IN ROOT = C:\Users\pc\Desktop\mov_sist\valid_tracks_700\Metamoeba leningradensis\Induccion leningradensis 11.63
#
# [18-Jul-23 19:09:05]
# There are 11 files in C:\Users\pc\Desktop\mov_sist\valid_tracks_700\Metamoeba leningradensis\Induccion leningradensis 11.63
# [18-Jul-23 19:09:19] 	- video 2020.09.02_15.35.31.xlsx contains 5.0 tracks, of which
#         5 end on the left side and 0 end on the right side, with ratios
#         100.0% left and 0.0% right
# [18-Jul-23 19:09:34] 	- video 2020.09.02_17.26.56.xlsx contains 5.0 tracks, of which
#         4 end on the left side and 1 end on the right side, with ratios
#         80.0% left and 20.0% right
# [18-Jul-23 19:09:49] 	- video 2020.09.02_19.07.18.xlsx contains 5.0 tracks, of which
#         4 end on the left side and 1 end on the right side, with ratios
#         80.0% left and 20.0% right
# [18-Jul-23 19:10:13] 	- video 2020.09.03_14.34.34.xlsx contains 8.0 tracks, of which
#         2 end on the left side and 6 end on the right side, with ratios
#         25.0% left and 75.0% right
# [18-Jul-23 19:10:33] 	- video 2020.09.03_16.49.50.xlsx contains 7.0 tracks, of which
#         7 end on the left side and 0 end on the right side, with ratios
#         100.0% left and 0.0% right
# [18-Jul-23 19:10:54] 	- video 2020.09.04_13.01.03.xlsx contains 7.0 tracks, of which
#         7 end on the left side and 0 end on the right side, with ratios
#         100.0% left and 0.0% right
# [18-Jul-23 19:11:14] 	- video 2020.09.04_15.07.45.xlsx contains 7.0 tracks, of which
#         7 end on the left side and 0 end on the right side, with ratios
#         100.0% left and 0.0% right
# [18-Jul-23 19:11:34] 	- video 2020.09.09_12.51.41.xlsx contains 7.0 tracks, of which
#         3 end on the left side and 4 end on the right side, with ratios
#         42.857142857142854% left and 57.14285714285714% right
# [18-Jul-23 19:11:58] 	- video 2020.09.10_11.18.39.xlsx contains 8.0 tracks, of which
#         0 end on the left side and 8 end on the right side, with ratios
#         0.0% left and 100.0% right
# [18-Jul-23 19:12:16] 	- video 2020.09.10_13.35.49.xlsx contains 6.0 tracks, of which
#         4 end on the left side and 2 end on the right side, with ratios
#         66.66666666666666% left and 33.33333333333333% right
# [18-Jul-23 19:12:40] 	- video 2020.09.10_19.24.24.xlsx contains 8.0 tracks, of which
#         0 end on the left side and 8 end on the right side, with ratios
#         0.0% left and 100.0% right
# [18-Jul-23 19:12:40] Max and min number of cells per rep in Induccion leningradensis 11.63 are 5.0-8.0
# [18-Jul-23 19:12:40] Induccion leningradensis 11.63 has 11 replicates (videos)
# [18-Jul-23 19:12:40] Induccion leningradensis 11.63 contains 73.0 tracks
# [18-Jul-23 19:12:40] Tracks in Induccion leningradensis 11.63 displacement values:
# -77.25
# -96.75
# -72.792
# -109.167
# -82.521
# -99.625
# -110.584
# -147.66699999999997
# -136.75000000000003
# 27.25
# -99.917
# -17.5
# -86.75
# -48.125
# 84.33300000000003
# -18.0
# -87.31200000000001
# 72.167
# 24.625
# 123.16699999999997
# 113.25
# 48.33300000000003
# 98.667
# -64.75
# -89.37400000000001
# -97.667
# -98.14599999999999
# -55.0
# -59.708
# -74.833
# -0.6259999999999764
# -108.813
# -67.93700000000001
# -73.708
# -53.27000000000001
# -108.53199999999998
# -98.031
# -103.75
# -125.25
# -110.75
# -78.0
# -109.0
# -92.375
# -94.875
# -25.708
# -54.75
# -53.583
# 43.917
# 43.75
# 21.665999999999997
# 40.25
# 72.75
# 73.12400000000002
# 72.62400000000002
# 93.875
# 54.93799999999999
# 53.93700000000001
# 104.833
# 50.5
# -50.75
# -24.5
# -24.25
# -24.75
# 0.75
# 75.41699999999997
# 43.16699999999997
# 12.937999999999988
# 42.874000000000024
# 116.5
# 35.375
# 87.33300000000003
# 61.625
# 59.50000000000003
# [18-Jul-23 19:12:40] Induccion leningradensis 11.63 has 30 cells to the right
# [18-Jul-23 19:12:40] Induccion leningradensis 11.63 has 43 cells to the left
# [18-Jul-23 19:12:40] Induccion leningradensis 11.63 has 58.9041095890411 left side ratio
# [18-Jul-23 19:12:40] Induccion leningradensis 11.63 has 41.0958904109589 right side ratio
# [18-Jul-23 19:12:40]
# NOW IN ROOT = C:\Users\pc\Desktop\mov_sist\valid_tracks_700\Metamoeba leningradensis\Quimiotaxis leningradensis varios ppmm
#
# [18-Jul-23 19:12:40]
# There are 9 files in C:\Users\pc\Desktop\mov_sist\valid_tracks_700\Metamoeba leningradensis\Quimiotaxis leningradensis varios ppmm
# [18-Jul-23 19:12:55] 	- video 2020.07.22_17.26.53.xlsx contains 5.0 tracks, of which
#         3 end on the left side and 2 end on the right side, with ratios
#         60.0% left and 40.0% right
# [18-Jul-23 19:13:19] 	- video 2020.07.22_19.13.10.xlsx contains 8.0 tracks, of which
#         7 end on the left side and 1 end on the right side, with ratios
#         87.5% left and 12.5% right
# [18-Jul-23 19:13:33] 	- video 2020.07.23_17.19.47.xlsx contains 5.0 tracks, of which
#         2 end on the left side and 3 end on the right side, with ratios
#         40.0% left and 60.0% right
# [18-Jul-23 19:13:48] 	- video 2020.07.23_19.15.42.xlsx contains 5.0 tracks, of which
#         5 end on the left side and 0 end on the right side, with ratios
#         100.0% left and 0.0% right
# [18-Jul-23 19:14:12] 	- video 2020.07.23_21.05.02.xlsx contains 8.0 tracks, of which
#         7 end on the left side and 1 end on the right side, with ratios
#         87.5% left and 12.5% right
# [18-Jul-23 19:14:33] 	- video 2020.07.24_11.57.57.xlsx contains 7.0 tracks, of which
#         7 end on the left side and 0 end on the right side, with ratios
#         100.0% left and 0.0% right
# [18-Jul-23 19:14:57] 	- video 2020.07.24_15.44.43.xlsx contains 8.0 tracks, of which
#         6 end on the left side and 2 end on the right side, with ratios
#         75.0% left and 25.0% right
# [18-Jul-23 19:15:20] 	- video 2020.07.24_17.42.44.xlsx contains 8.0 tracks, of which
#         8 end on the left side and 0 end on the right side, with ratios
#         100.0% left and 0.0% right
# [18-Jul-23 19:15:39] 	- video 2020.07.24_19.32.29.xlsx contains 6.0 tracks, of which
#         5 end on the left side and 1 end on the right side, with ratios
#         83.33333333333334% left and 16.666666666666664% right
# [18-Jul-23 19:15:39] Max and min number of cells per rep in Quimiotaxis leningradensis varios ppmm are 5.0-8.0
# [18-Jul-23 19:15:39] Quimiotaxis leningradensis varios ppmm has 9 replicates (videos)
# [18-Jul-23 19:15:39] Quimiotaxis leningradensis varios ppmm contains 60.0 tracks
# [18-Jul-23 19:15:39] Tracks in Quimiotaxis leningradensis varios ppmm displacement values:
# -51.958999999999946
# -62.68700000000001
# -1.875
# 4.75
# 48.625
# -49.666
# -35.833999999999946
# -97.04199999999997
# -5.416000000000054
# -19.665999999999997
# -17.5
# -42.06299999999999
# 56.75
# -65.58300000000003
# -154.375
# 181.5
# 22.625
# 62.875
# -35.41699999999997
# -20.874000000000024
# -25.416000000000054
# -53.916000000000054
# -28.666000000000054
# -99.16600000000003
# -161.25
# -95.06299999999999
# -38.75
# -29.833000000000027
# -58.25
# -63.458999999999946
# 15.416999999999973
# -15.166999999999973
# -30.833000000000027
# -26.625
# -31.041999999999973
# -51.58300000000003
# -13.5
# -46.06200000000001
# -50.0
# -49.43799999999999
# 0.8120000000000118
# 3.75
# -30.25
# -58.25
# -3.5
# -88.166
# -53.031000000000006
# -25.415999999999997
# -35.25
# -48.25
# -12.042000000000002
# -68.14599999999999
# -87.167
# -66.292
# -25.0
# -43.00000000000003
# -12.770999999999987
# -19.812999999999988
# 11.656999999999982
# -4.312000000000012
# [18-Jul-23 19:15:39] Quimiotaxis leningradensis varios ppmm has 10 cells to the right
# [18-Jul-23 19:15:39] Quimiotaxis leningradensis varios ppmm has 50 cells to the left
# [18-Jul-23 19:15:39] Quimiotaxis leningradensis varios ppmm has 83.33333333333334 left side ratio
# [18-Jul-23 19:15:39] Quimiotaxis leningradensis varios ppmm has 16.666666666666664 right side ratio
# [18-Jul-23 19:15:39]
# NOW IN ROOT = C:\Users\pc\Desktop\mov_sist\valid_tracks_700\Metamoeba leningradensis\Sin estimulo leningradensis 11.63
#
# [18-Jul-23 19:15:39]
# There are 7 files in C:\Users\pc\Desktop\mov_sist\valid_tracks_700\Metamoeba leningradensis\Sin estimulo leningradensis 11.63
# [18-Jul-23 19:16:00] 	- video 2020.07.27_11.55.49.xlsx contains 7.0 tracks, of which
#         6 end on the left side and 1 end on the right side, with ratios
#         85.71428571428571% left and 14.285714285714285% right
# [18-Jul-23 19:16:14] 	- video 2020.07.27_12.47.35.xlsx contains 5.0 tracks, of which
#         3 end on the left side and 2 end on the right side, with ratios
#         60.0% left and 40.0% right
# [18-Jul-23 19:16:38] 	- video 2020.07.27_13.46.19.xlsx contains 8.0 tracks, of which
#         4 end on the left side and 4 end on the right side, with ratios
#         50.0% left and 50.0% right
# [18-Jul-23 19:17:03] 	- video 2020.07.27_14.48.01.xlsx contains 8.0 tracks, of which
#         2 end on the left side and 6 end on the right side, with ratios
#         25.0% left and 75.0% right
# [18-Jul-23 19:17:23] 	- video 2020.07.27_15.41.43.xlsx contains 7.0 tracks, of which
#         3 end on the left side and 4 end on the right side, with ratios
#         42.857142857142854% left and 57.14285714285714% right
# [18-Jul-23 19:17:48] 	- video 2020.07.27_17.31.44.xlsx contains 8.0 tracks, of which
#         4 end on the left side and 4 end on the right side, with ratios
#         50.0% left and 50.0% right
